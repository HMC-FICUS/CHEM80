# %% [markdown]
# # CHEM60 - Assignment #8 - To Ge or Not to Ge: Milling Towards an Optimized Reaction
#
# This name is very bad. I am medium sorry.
#
# To get started, click on '**File**' in the left menu, then '**Save a copy in Drive**' to ensure you are editing *your* version of this assignment (if you don't, your changes won't be saved!). Then, share the notebook with Prof Kavassalis (skavassalis@g.hmc.edu). This will make it easier for us to look at the notebook if you need help after class.
#
# First things first, open up the Glavinović et al. paper ([via Science Advances](https://www.science.org/doi/10.1126/sciadv.1700149) or in the [Drive](https://drive.google.com/file/d/1a3lKZfEsNJs1bN9ARpCnZbuJCxlXlHlT/view?usp=share_link) and its [supplement](https://drive.google.com/file/d/1hsG2k57DkgNz-Cif_8dFqamYgOk0QYQC/view?usp=share_link), and give it a read. Spend some time going through the supplement to see what data is there. You do not need to understand every detail in the paper, but look for key ideas, motivation, and methods for this week;* focus on the reaction optimization parts*.

# %% [markdown]
# # Imports
#
# If you need to add imports, come back and add them here. I grabbed everything from the in-class notebook (some of which, you might not use here).

# %%
# Third party imports
import matplotlib.colors as colours  # Library for defining colours for plotting
import matplotlib.pyplot as plt  # Library for creating plots and visualizations
import numpy as np  # Library for numerical computing
import pandas as pd  # Library for data manipulation and analysis
import plotly.graph_objects as go  # Library for creating interactive plots
from statsmodels.stats.multicomp import pairwise_tukeyhsd # a stats test we'll use
from scipy import linalg  # Library for linear algebra operations
from scipy.stats import distributions # Module that loads in pre-made statistical distributions
from scipy.stats import f # Module for F statistics to get P-values
from scipy.interpolate import griddata  # Module for data interpolation on a grid

# This part of the code block is telling matplotlib to make certain font sizes exra, extra large by default
# Here is where I list what parametres I want to set new defaults for
params = {'legend.fontsize': 'xx-large',
         'axes.labelsize': 'xx-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'xx-large',
         'ytick.labelsize':'xx-large'}
plt.rcParams.update(params)

# below sets up some custom colour maps for certain visualizations
# colour blind friendly colour map (blue )
cmap_hex_temp = ['#2c7bb6','#abd9e9','#ffffbf','#fdae61','#d7191c']
cmap_RBG_temp = [colours.to_rgb(cmap_hex_temp[i]) for i in range(len(cmap_hex_temp))]
cmap_temp = colours.LinearSegmentedColormap.from_list('cmap',cmap_RBG_temp,N=256)
# Calculate color level values for each color
colour_levels = [i/float(len(cmap_hex_temp)-1) for i in range(len(cmap_hex_temp))]
# Create the colorscale list for Plotly
colourscale = [[colour_levels[i], cmap_hex_temp[i]] for i in range(len(cmap_hex_temp))]

# %% [markdown]
# # Q1. Any collaborators? (0 marks)
#
# Working together is encouraged. If you worked with a classmate or two, list their names here.
#
#
# ---

# %% [markdown]
# **names maybe?**

# %% [markdown]
# ---

# %% [markdown]
# # Q2. What data collection methods does this paper describe? (1 marks)
#
# Just a couple sentences will do. We focussed on the PXRD data in class, but they have a bit more going on.
#
#
#
# ---

# %% [markdown]
# **Your answer here**

# %% [markdown]
# ---

# %% [markdown]
# # Q3. List how many reaction parameters the authors optimized (ie. how many dimensions is this parameter space) AND describe which ones make use of the PXRD data in a way we could quantify for optimization (3 marks)
#
# The supplement is probably the fastest way to find this out. For the second part, I am asking which variables (things they varied) make use of actual peak differences and which ones use other qualities.

# %% [markdown]
# ---

# %% [markdown]
# **text**

# %% [markdown]
# ---

# %% [markdown]
# #Q4. Convince yourself with stats - that the 180-minute milling time is the optimal condition (of the ones that they checked) INCLUDE A PLOT (15 marks)
#
# You will need to make some fake data here! Go to the **Optimization of milling time** section from the in-class notebook and grab the `all_params` object defined below (ie. the thing that I set up to help us make fake PXRD data that looks like theirs).
#
# Then, go to the **Which is best?** section, and remember how we made the fake data set with repeated measurements (to quantify statistics).
#
# Once you have the `peak_values` object (you can name it whatever you want), make a plot to show the variance between samples (like the one you find under **Adding some stats to our plot**).
#
# Then, do an ANOVA analysis to confirm that the four milling times tested are actually unique.
#
# Finally, use the Tukey HSD test to confirm which is the best time.
#
#
#
# ---

# %%
# code block

# %% [markdown]
# **text block**

# %% [markdown]
# ---

# %% [markdown]
# # Q Bonus. Could you set up a better optimization scheme?
#
# Yes, I wrote this before Question 5.
#
# Bonus marks for any attempts at putting the experimental optimization steps in the form of the Prof. VR optimization scheme described at the end of the in-class notebook (it is completely doable, but you'll need to make a bit more fake data and only include the parameters that actually impact the reactant peak areas (ie. the ones you id'd as quantifiable above). Bonus mark amount will be based on how much you get to work!
#
# If you like this kind of math, this will be very fun!
#
#
# ---

# %%
# code!

# %% [markdown]
# ---

# %% [markdown]
# #Q5. What is missing for you? (1 mark)
#
# What in this paper (or in-class this week) didn't make sense (*and* that you *want* to understand more deeply)?
#
#
# ---

# %% [markdown]
# **your answer**

# %% [markdown]
# ---

# %% [markdown]
# # Submit your notebook
#
# It's time to download your notebook and submit it on Canvas. Go to the File menu and click **Download** -> **Download .ipynb**
#
#
# Then, go to **Canvas** and **submit your assignment** on the assignment page. It should look something like this:
#
# Once it is submitted, you are done!
