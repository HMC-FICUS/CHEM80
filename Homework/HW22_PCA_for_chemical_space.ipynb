# %% [markdown]
# # CHEM60 - Assignment #22 - PCA for mapping chemical space
#
# Let's try to do more with the data now.
#
# To get started, click on '**File**' in the left menu, then '**Save a copy in Drive**' to ensure you are editing *your* version of this assignment (if you don't, your changes won't be saved!). Then, share the notebook with Prof Kavassalis (skavassalis@g.hmc.edu). This will make it easier for us to look at the notebook if you need help after class.

# %% [markdown]
# # Imports
#
# If you need to add imports, come back and add them here.

# %%
# Standard library imports
import math as m

# Third party imports
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans # for pre-built clustering
from sklearn.decomposition import PCA # and PCA
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # and normalization


# This part of the code block is telling matplotlib to make certain font sizes exra, extra large by default
params = {'legend.fontsize': 'xx-large',
         'axes.labelsize': 'xx-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'xx-large',
         'ytick.labelsize':'xx-large'}
# This line updates the default parameters of pyplot (to use our larger fonts)
plt.rcParams.update(params)

# %% [markdown]
# And to load the data:

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# From here:

# %%
df = pd.read_csv('/content/gdrive/Shared drives/Chem_60_Spring_2024/In_Class_Notebooks/data/CHEM60_Class22_data_Jover_etal.csv')

# %% [markdown]
# ---

# %% [markdown]
# # Q1. Any co-workers this week (0 marks)
#
# Names, as always
#
#
# ---

# %% [markdown]
# **names?**

# %% [markdown]
# ---

# %% [markdown]
# # Q2. Go back to the [review paper](https://bmcchem.biomedcentral.com/articles/10.1186/s13065-015-0104-5) and check out the [original source](https://pubs.acs.org/doi/10.1021/om100648v) too to look at *Table 5. Descriptor Loadings*. Describe what is different about the PCA and cluster results in the in-class notebook and the ones in the paper. Qualitative and quantitative differences exist here.  (5 marks)
#
#
#
# ---

# %% [markdown]
# **Your paragraph**

# %% [markdown]
# ---

# %% [markdown]
# # Q3. Let's think about the normalization schemes again. Compare the distributions of (ie. make histograms) 5 variables from the original dataset of your choosing under the different normalization schemes. (5 marks)
#
# Full marks for:
# * Stating what the 5 variables you picked physically (chemically) represent (you'll likely have to do some reading)
# * A histogram showing the distribution before normalization for each variable
# * Three additional histograms for each variable showing how the distributional values change with different normalization schemes
#
# Many classic PCA tutorials do PCA on data sets where all the original features are the same type of thing with the same distributions. When people use PCA for chemical space search, some of these variables are extremely different from one another. Normalization can feel like a simple choice when you are comparing 'like' features but you just want their magnitudes to be the same. But it is a less trivial choice when comparing features that have extremely different physical meaning.
# ---

# %% [markdown]
# **your answer**

# %%
# code!

# %% [markdown]
# ---

# %% [markdown]
# #Q4. Use PCA to determine which normalization scheme was best for this data set! (10 marks)
#
# We want to make our preprocessing decisions such that our PCA is most effective - ie. that we can describe the maximum variance in the system with the smallest number of components. Compare the three normalization schemes from the prospective of the Scree Plot.
#
# Full marks for creating a **Scree Plot** with **three lines** on it, **labeled**, for each normalization scheme AND a **sentence or two explaining** why that tells you which preprocessing method was best for this data.
#
#
# ---

# %%
# code!

# %% [markdown]
# **text**

# %% [markdown]
# ---

# %% [markdown]
# # Q5. What is still different from your above PCA results and the ones in the paper? What would you absolutely need to know (what kind of details) to recreate their analysis exactly? Why does this matter (for science!)? (2 marks).
#
#
#
# ---

# %% [markdown]
# **text**

# %% [markdown]
# #Q6. What is missing for you? (1 mark)
#
# What didn't make sense (*and* that you *want* to understand more deeply)? I'll give you comments next week for this one and any old assignments I haven't uploaded comments for yet.
#
# ---

# %% [markdown]
# **your answer**

# %% [markdown]
# ---

# %% [markdown]
# # Submit your notebook
#
# It's time to download your notebook and submit it on Canvas. Go to the File menu and click **Download** -> **Download .ipynb**
#
#
# Then, go to **Canvas** and **submit your assignment** on the assignment page. It should look something like this:
#
# Once it is submitted, you are done!
