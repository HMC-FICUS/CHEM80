# %% [markdown]
# # CHEM60 - Assignment #12 - Hungry for Energy: A Greedy Algorithm's Pathway to Reactions
#
# I don't know what say about this one.
#
# To get started, click on '**File**' in the left menu, then '**Save a copy in Drive**' to ensure you are editing *your* version of this assignment (if you don't, your changes won't be saved!). Then, share the notebook with Prof Kavassalis (skavassalis@g.hmc.edu). This will make it easier for us to look at the notebook if you need help after class.
#
# Time to go!

# %% [markdown]
# # Imports
#
# If you need to add imports, come back and add them here. I grabbed everything from the in-class notebook (some of which, you might not use here).

# %%
# Standard library imports
import math as m

# Third party imports
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import numpy as np

# This part of the code block is telling matplotlib to make certain font sizes exra, extra large by default
# Here is where I list what parametres I want to set new defaults for
params = {'legend.fontsize': 'xx-large',
         'axes.labelsize': 'xx-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'xx-large',
         'ytick.labelsize':'xx-large'}
# This line updates the default parameters of pyplot (to use our larger fonts)
plt.rcParams.update(params)

# %% [markdown]
# And mount the Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Let's load the data so it's ready to go

# %%
data = np.load("/content/gdrive/Shared drives/Chem_60_Spring_2024/In_Class_Notebooks/data/class12_PES_hydrogen_exchange.npz")
dist_AB_g = data['dist_AB_g']
dist_BC_g = data['dist_BC_g']
energy_g = data['energy_g']

# %% [markdown]
# # Q1. Any collaborators? (0 marks)
#
# Working together is encouraged. If you worked with a classmate or two, list their names here.
#
#
# ---

# %% [markdown]
# **names maybe?**

# %% [markdown]
# ---

# %% [markdown]
# # Q2. You are going to extend the greedy algorithm at the end of the in-class assignment. Write me pseudo-code (talk through the logic) for this task (4 marks)
#
# Our goal is to travel between the two local minima on the path (or paths) that minimize energy steps. What logic needs to be followed? If energy steps are statistically equivalent in several directions, that means we need to make multiple paths (how would we decide this). We could easily make too many paths! How should we decide to get rid of paths? Perhaps after a certain number of unique paths are generated, remove the ones with the highest cumulative energy (those will be the least likely to occur, after all). Write out the logic of what you would want to do in a function.
#
#
# ---

# %% [markdown]
# **Your answer here**

# %% [markdown]
# ---

# %% [markdown]
# # Q3. Now implement what you wrote and test it out! (15 marks)
#
# Full marks will be awarded for something that lets you travel between the two local minima through a plausibly low energy path (ie. follow the valley, don't randomly climb the mountain then fall down). It is okay if you generate many paths or only just one in the end. It cannot be identical to the in-class version, but you can certainly start there and modify.

# %% [markdown]
# ---

# %%
# lots here!

# %% [markdown]
# ---

# %% [markdown]
# # Q4. Why do we need paths through PES and not just the height of the energy barrier of some intermediate to truly predict reactions? (2 pts)
#
# Think about what is happening the more dimensions we add. Think about cases where an energy barrier might seem reasonable, but a path is hard to find!
#
#
# ---

# %% [markdown]
# **your answer**

# %% [markdown]
# #Q5. What is missing for you? (1 mark)
#
# Another huge one. What didn't make sense (*and* that you *want* to understand more deeply)?
#
#
# ---

# %% [markdown]
# **your answer**

# %% [markdown]
# ---

# %% [markdown]
# # Submit your notebook
#
# It's time to download your notebook and submit it on Canvas. Go to the File menu and click **Download** -> **Download .ipynb**
#
#
# Then, go to **Canvas** and **submit your assignment** on the assignment page. It should look something like this:
#
# Once it is submitted, you are done!
