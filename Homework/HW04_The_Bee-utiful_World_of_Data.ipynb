# %% [markdown]
# # CHEM60 - Assignment #4 - The Bee-utiful World of Data
#
# I love puns. I am sorry.
#
#
# To get started, click on '**File**' in the left menu, then '**Save a copy in Drive**' to ensure you are editing *your* version of this assignment (if you don't, your changes won't be saved!). Then, share the notebook with Prof Kavassalis (skavassalis@g.hmc.edu). This will make it easier for us to look at the notebook if you need help after class.
#
# First things first, open up the Nicholson and Knapp et al. paper ([via Nature](https://www.nature.com/articles/s41586-023-06773-3) or in the [Drive](https://drive.google.com/file/d/1zxrqQ9-7RohHP2kHw42-B8wi2ZbsOlRb/view?usp=share_link)), and give it a read. This won't be the ~ 5 minute read you did in the first class. Spend some time going through as much of it as you can. You do not need to understand ever single detail in the paper, but look for key ideas, the motivation, the methods, and for this week, *focus on the stats*.

# %% [markdown]
# # Imports
#
# If you need to add imports, come back and add them here.

# %%
# Standard library imports
import math as m

# Third party imports
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# This part of the code block is telling matplotlib to make certain font sizes exra, extra large by default
# Here is where I list what parametres I want to set new defaults for
params = {'legend.fontsize': 'xx-large',
         'axes.labelsize': 'xx-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'xx-large',
         'ytick.labelsize':'xx-large'}
# This line updates the default parameters of pyplot (to use our larger fonts)
plt.rcParams.update(params)

# %% [markdown]
# Next, mount the Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# # Q1. Any collaborators? (0 marks)
#
# Working together is encouraged. If you worked with a classmate or two, list their names here.
#
#
# ---

# %% [markdown]
# **names maybe?**

# %% [markdown]
# ---

# %% [markdown]
# # Q2. What data collection methods does this paper describe? (2 marks)
#
# Just a couple sentences will do. Think about the dataset we loaded (that you'll load again soon). What is in there? How did it get there?
#
#
#
# ---

# %% [markdown]
# **Your answer here**

# %% [markdown]
# ---

# %% [markdown]
# # Q3. Show me the stats! What statistical measures and moments appear in this paper AND check them yourselves with the data the authors provided (7 marks)
#
# Let's reload the data set behind this paper. There are lots of means, standard deviations, and ranges included in this paper. Grab the specific numbers the authors present in the paper and calculate them yourself from the data provided (look at you, becoming awesome peer reviewers!). It's worth 7 marks, so find me 7 things to talk about. Make as many code and text boxes as you need.

# %%
NicholsonKnapp_etal_2023 = pd.read_csv('/content/gdrive/Shared drives/Chem_60_Spring_2024/In_Class_Notebooks/data/class4_NicholsonKnapp_etal_2023_BombusPesticideEffects.csv', index_col=0)

# %% [markdown]
# ---

# %%
# some code

# %% [markdown]
# **and text boxes will be needed**

# %% [markdown]
# ---

# %% [markdown]
# #Q4. Recreate a plot (or, a panel of a plot)! AND explain what information it is conveying (10 marks)
#
# Recreate a panel of a plot from the paper (that is not Fig. 1). You can create an entire multiplot, but you don't have to for full marks on this. Just like as in the in-class material, if you make one panel, that will do. The Extended Figure section has a lot of good options too. You can use the `numpy` stats options (`np.mean()`, `np.stdev()`, `np.percentile()`, etc.) or write your own functions. These measures are fairly basic, so I am not concerned about assessing your ability to write code to find these quantities.
#
# While you can skip fit lines (I actually encourage that because there are some subtleties to the mixed effect methods used here), basic figure components need to be present (see the 'Pesticide risk vs weight gain' and 'Pesticide risk vs total production' sections in the in-class material for examples).
#
# Full marks will be given for a complete panel AND a few sentences explaining why this figure tells us something meaningful.
#
# ---

# %%
# code block

# %% [markdown]
# **text block**

# %% [markdown]
# ---

# %% [markdown]
# #Q5. What is missing for you? (1 mark)
#
# What in this paper (or in-class this week) didn't make sense (*and* that you *want* to understand more deeply)?
#
#
# ---

# %% [markdown]
# **your answer**

# %% [markdown]
# ---

# %% [markdown]
# # Submit your notebook
#
# It's time to download your notebook and submit it on Canvas. Go to the File menu and click **Download** -> **Download .ipynb**
#
#
# Then, go to **Canvas** and **submit your assignment** on the assignment page. It should look something like this:
#
# Once it is submitted, you are done!
