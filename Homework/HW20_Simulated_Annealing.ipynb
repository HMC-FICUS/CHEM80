# %% [markdown]
# # CHEM60 - Assignment #20 - Simulated annealing
#
# Simulated annealing is an extension of the Metropolis algorithm. In the simplest sense, it *is* the Metropolis algorithm, but now temperature can vary throughout the length of simulation.
#
# To get started, click on '**File**' in the left menu, then '**Save a copy in Drive**' to ensure you are editing *your* version of this assignment (if you don't, your changes won't be saved!). Then, share the notebook with Prof Kavassalis (skavassalis@g.hmc.edu). This will make it easier for us to look at the notebook if you need help after class.

# %% [markdown]
# # Imports
#
# If you need to add imports, come back and add them here.

# %%
# Standard library imports
import math as m

# Third party imports
import matplotlib.animation as animation
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from matplotlib import rc
import numpy as np
from scipy.stats import chisquare

# so the notebook shows an animation
rc('animation', html='html5')

# This part of the code block is telling matplotlib to make certain font sizes exra, extra large by default
params = {'legend.fontsize': 'xx-large',
         'axes.labelsize': 'xx-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'xx-large',
         'ytick.labelsize':'xx-large'}
# This line updates the default parameters of pyplot (to use our larger fonts)
plt.rcParams.update(params)

# %% [markdown]
# ---

# %% [markdown]
# # Q1. Any co-workers this week (0 marks)
#
# Names, as always
#
#
# ---

# %% [markdown]
# **names?**

# %% [markdown]
# ---

# %% [markdown]
# # Q2. Read the [Simulated Annealing paper](https://drive.google.com/file/d/1SLNC6NVI_ZyAd252y2lFrzARp-nSAgUW/view?usp=drive_link) and give a high level summary of what it is doing and how it is **both** related and different from Metropolis (5 marks)
#
# This paper extends the chemistry analogy but applies it to a problem that was very central to 1980s computer science! Chemistry informing computing.
#
#
# ---

# %% [markdown]
# **Your paragraph**

# %% [markdown]
# ---

# %% [markdown]
# # Q3. Thankfully, as soon as Simulated Annealing was used by computer scientists, chemists stole it right back. Find a chemistry paper (a Google Scholar search for something like 'simulated annealing applied to chemistry' will do) that uses simulated annealing to solve a chemistry problem that *interests* you. (10 marks)
#
# Full marks for:
# * a complete citation of the paper (I am not particular about style, but I'd need to be able to find it)
# * A summary of what chemistry question the paper was trying to answer.
# * A description of how simulated annealing was used to answer the cool chemistry thing in the paper
#
#
# You will notice doing the search that the applications are very, very broad! A significant number of the optimization tasks we've done this semester can be done with simulated annealing. So can many types of chemical simulation! This basic logic and math is so general and wildly powerful. And it wouldn't exist without chemistry lending the analogy that made it make sense. I really want you to remember it.
# ---

# %% [markdown]
# **your answer**

# %% [markdown]
# ---

# %% [markdown]
# #Q4. Write and demonstrate an algorithm for simulated annealing! (10 marks)
#
# Full marks will be awarded for a function incorporates simulated annealing into the Metropolis algorithm and a demonstration of it (you can just use the particles moving around example from the in-class notebook or create something new for bonus marks and joy). So, make a video, like we did with Metropolis, but allow your system to 'cool' over time.
#
# To do this, you can make the temperature (`kT` in this case) dependent on the simulation time or the current frame number, gradually decreasing it as the simulation proceeds. Simulated annealing usually starts with a higher temperature that allows the system to explore a larger portion of the state space and then slowly cools down, narrowing down the exploration while seeking the minimum energy state, as the system starts to "settle".
#
# A simple way to incorporate a cooling scheme might look like:
#
# `# Cooling schedule: In this example, kT decreases linearly with frames.`
# `kT = kT_init * (1 - frame / max_frames)`
#
# With perhaps some very helpful check to make sure that this number does not go below 0.
#
#
# ---

# %%
# code!

# %% [markdown]
# Hi, when you have multiple code blocks next to each other, please use markdown to seperate them to make it easier to read! Ideally, it should be telling the reader something useful too!

# %%
# another code block?

# %% [markdown]
# ---

# %% [markdown]
# #Q5. What is missing for you? (1 mark)
#
# What didn't make sense (*and* that you *want* to understand more deeply)? Do you also think this topic is super, super cool?? (It's okay if you don't...)
#
# ---

# %% [markdown]
# **your answer**

# %% [markdown]
# ---

# %% [markdown]
# # Submit your notebook
#
# It's time to download your notebook and submit it on Canvas. Go to the File menu and click **Download** -> **Download .ipynb**
#
#
# Then, go to **Canvas** and **submit your assignment** on the assignment page. It should look something like this:
#
# Once it is submitted, you are done!
