# %% [markdown]
# # CHEM60 - Assignment #10 - Peak-ing into a mystery
#
# Naming assignments is my super power (it is not...).
#
# To get started, click on '**File**' in the left menu, then '**Save a copy in Drive**' to ensure you are editing *your* version of this assignment (if you don't, your changes won't be saved!). Then, share the notebook with Prof Kavassalis (skavassalis@g.hmc.edu). This will make it easier for us to look at the notebook if you need help after class.
#
# Time to go!

# %% [markdown]
# # Imports
#
# If you need to add imports, come back and add them here. I grabbed everything from the in-class notebook (some of which, you might not use here).

# %%
# Standard library imports
import math as m

# Third party imports (a ton of plotting things today!)
import matplotlib.animation as animation
import matplotlib.cm as cm
from matplotlib.cm import get_cmap
import matplotlib.colors as mcolors
from matplotlib.colors import LogNorm
from matplotlib.lines import Line2D
import matplotlib.image as mpimg
import matplotlib.patches as patches
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import matplotlib.transforms as transforms
from matplotlib import rc

import numpy as np
import pandas as pd
import urllib.request

# so the notebook shows an animation
rc('animation', html='html5')

# This part of the code block is telling matplotlib to make certain font sizes exra, extra large by default
# Here is where I list what parametres I want to set new defaults for
params = {'legend.fontsize': 'xx-large',
         'axes.labelsize': 'xx-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'xx-large',
         'ytick.labelsize':'xx-large'}
# This line updates the default parameters of pyplot (to use our larger fonts)
plt.rcParams.update(params)

# %% [markdown]
# And mount the Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# Let's load the data

# %%
# load the dataframe
df = pd.read_csv('/content/gdrive/Shared drives/Chem_60_Spring_2024/In_Class_Notebooks/data/class10_Van_Heuvelen.csv')

# create the first dataframe for IR1
IR1_df = df[['IR1_190627_x', 'IR1_190627_y']].copy()
IR1_df.set_index('IR1_190627_x', inplace=True)
IR1_df.index.name = 'wavenumber'

# create the second dataframe
IR2_df = df[['IR2_190627_x', 'IR2_190627_y']].copy()
IR2_df.set_index('IR2_190627_x', inplace=True)
IR2_df.index.name = 'wavenumber'

# %% [markdown]
# And remind yourself of the inspiration
#
# ![Slide from Prof. Van Heuvelen showing the IR spectra for the pink compound, two traces appear on the plot, one for the version made with sodium borohydride and one for the version made with deuterated sodium borohydride](https://kavassalis.space/s/KVH_slide57.png)
# #### Slide from Prof. Van Heuvelen - Something is important here, and different between the two spectra plotted. How could we begin to extract the differences between these two spectra?

# %% [markdown]
# # Q1. Any collaborators? (0 marks)
#
# Working together is encouraged. If you worked with a classmate or two, list their names here.
#
#
# ---

# %% [markdown]
# **names maybe?**

# %% [markdown]
# ---

# %% [markdown]
# # Q2. You are going to design software to perform peak-fitting of IR spectra. Write me pseudo-code (talk through the logic) for this software (4 marks)
#
# Our goal is to **say something quantitative about what is different between the above two spectra** (so we can start figuring out the story: we need to know what this compound *is* so we can figure out how it facilitates removing halogenated pollutants!).
#
# What do we need to do? Walk through the steps of finding the peaks and finding the parameters for the peaks (no integration needed today).
#
#
#
# ---

# %% [markdown]
# **Your answer here**

# %% [markdown]
# ---

# %% [markdown]
# # Q3. Now implement what you wrote and quantify at least a few difference between the spectra in the above figure! (15 marks)
#
# Full marks will be awarded for something that lets you compare the *height* of peaks between the two spectra for a region containing multiple peaks (It doesn't *have* to be the entire spectra! For the entire spectra, you should think about chopping it into windows after you have localized the peaks).
#
# You can write it as seperate functions that you call in sequence (like the in-class notebook) or as all one large function. Make sure you demonstrate it working! Make sure it includes the key parts from the in-class examples (peak localization, baseline correction, and Gauss-Newton fitting to output parameters that you can compare). Make sure you have thought about how many iterations you want Gauss-Newton to run per peak (when you do this for many peaks, it will be slow! but if your iteration number is too low, your fits will be bad <- ~*~ optimization ~*~)
#
# Full marks will *not* be awarded for using a library that already does all of this! Why? Because I want you to practice with the logic and code of creating something like this.

# %% [markdown]
# ---

# %%
# lots here!

# %% [markdown]
# ---

# %% [markdown]
# #Q4. What is missing for you? (1 mark)
#
# This is a big topic! What didn't make sense (*and* that you *want* to understand more deeply)?
#
#
# ---

# %% [markdown]
# **your answer**

# %% [markdown]
# ---

# %% [markdown]
# # Submit your notebook
#
# It's time to download your notebook and submit it on Canvas. Go to the File menu and click **Download** -> **Download .ipynb**
#
#
# Then, go to **Canvas** and **submit your assignment** on the assignment page. It should look something like this:
#
# Once it is submitted, you are done!
